# %%
# !python3 'C:\Users\user\Documents\GitHub\unet_cellseg\prog.py' --print-number 5
# Out:
# Python was not found but can be installed from the Microsoft Store: https://go.microsoft.com/fwlink?linkID=2082640
